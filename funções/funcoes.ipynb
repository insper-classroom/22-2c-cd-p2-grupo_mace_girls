# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import re

# %%
dados = pd.read_csv('../dados/titles.csv')
dados.tmdb_popularity.describe()
# Out:
# count    5759.000000
# mean       22.637925
# std        81.680263
# min         0.009442
# 25%         2.728500
# 50%         6.821000
# 75%        16.590000
# max      2274.044000
# Name: tmdb_popularity, dtype: float64

# %%
dados['Drama'] = dados['genres']
for i in range(0,len(dados)):
        lista = dados['genres'].iloc[i]
        if 'drama' in lista:
            dados['Drama'][i] = 1
        else:
            dados['Drama'][i] = 0

dados.head(1)
# Out:
# C:\Users\grupo\AppData\Local\Temp/ipykernel_12508/2503074335.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['Drama'][i] = 0
# C:\Users\grupo\AppData\Local\Temp/ipykernel_12508/2503074335.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['Drama'][i] = 1
#          id                                title  type  \
# 0  ts300399  Five Came Back: The Reference Films  SHOW
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
#
# ...

# %%
dados['comedia'] = dados['genres']
for i in range(0,len(dados)):
        lista = dados['genres'].iloc[i]
        if 'comedia' in lista:
            dados['comedia'][i] = 1
        else:
            dados['comedia'][i] = 0

dados.head(1)
# Out:
# C:\Users\grupo\AppData\Local\Temp/ipykernel_12508/615969179.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['comedia'][i] = 0
#          id                                title  type  \
# 0  ts300399  Five Came Back: The Reference Films  SHOW
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
#
#   age_certification  runtime             genres production_countries  seasons  \
# 0             TV-MA       51  ['documentation']               ['US']      1.0
#
#   imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score Drama comedia
# 0     NaN         NaN         NaN              0.6         NaN     0       0

# %%
dados['romance'] = dados['genres']
for i in range(0,len(dados)):
        lista = dados['genres'].iloc[i]
        if 'romance' in lista:
            dados['romance'][i] = 1
        else:
            dados['romance'][i] = 0

dados.head(1)
# Out:
# C:\Users\grupo\AppData\Local\Temp/ipykernel_12508/1051652357.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['romance'][i] = 0
# C:\Users\grupo\AppData\Local\Temp/ipykernel_12508/1051652357.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['romance'][i] = 1
#          id                                title  type  \
# 0  ts300399  Five Came Back: The Reference Films  SHOW
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
#
# ...

# %%
dados['action'] = dados['genres']
for i in range(0,len(dados)):
        lista = dados['genres'].iloc[i]
        if 'action' in lista:
            dados['action'][i] = 1
        else:
            dados['action'][i] = 0

dados.head(1)
# Out:
# C:\Users\grupo\AppData\Local\Temp/ipykernel_12508/59498740.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['action'][i] = 0
# C:\Users\grupo\AppData\Local\Temp/ipykernel_12508/59498740.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['action'][i] = 1
#          id                                title  type  \
# 0  ts300399  Five Came Back: The Reference Films  SHOW
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
#
# ...

# %%
dados['fantasy'] = dados['genres']
for i in range(0,len(dados)):
        lista = dados['genres'].iloc[i]
        if 'fantasy' in lista:
            dados['fantasy'][i] = 1
        else:
            dados['fantasy'][i] = 0

dados.head(1)
# Out:
# C:\Users\grupo\AppData\Local\Temp/ipykernel_12508/2357019316.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['fantasy'][i] = 0
# C:\Users\grupo\AppData\Local\Temp/ipykernel_12508/2357019316.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['fantasy'][i] = 1
#          id                                title  type  \
# 0  ts300399  Five Came Back: The Reference Films  SHOW
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
#
# ...

# %%
dados['horror'] = dados['genres']
for i in range(0,len(dados)):
        lista = dados['genres'].iloc[i]
        if 'horror' in lista:
            dados['horror'][i] = 1
        else:
            dados['horror'][i] = 0

dados.head(1)
# Out:
# C:\Users\grupo\AppData\Local\Temp/ipykernel_12508/3578763068.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['horror'][i] = 0
# C:\Users\grupo\AppData\Local\Temp/ipykernel_12508/3578763068.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['horror'][i] = 1
#          id                                title  type  \
# 0  ts300399  Five Came Back: The Reference Films  SHOW
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
#
# ...

# %%
# A target escolhida para avaliar quais filmes apresentam maior satisfação dos usuários foi a popularidade de acordo com o tmdb. Esta
# varia de 0.009442 a 2274.044000.

# Primeiro filtramos nossa base para avaliar somente os filmes:
filmes = dados.loc[dados.type=='MOVIE']
filmes.head()
# Out:
#          id                            title   type  \
# 1   tm84618                      Taxi Driver  MOVIE
# 2  tm154986                      Deliverance  MOVIE
# 3  tm127384  Monty Python and the Holy Grail  MOVIE
# 4  tm120801                  The Dirty Dozen  MOVIE
# 6   tm70993                    Life of Brian  MOVIE
#
#                                          description  release_year  \
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
# 6  Brian Cohen is an average young Jewish man, bu...          1979
#
#   age_certification  runtime                                       genres  \
# 1                 R      114                           ['drama', 'crime']
# 2                 R      109  ['drama', 'action', 'thriller', 'european']
# ...
